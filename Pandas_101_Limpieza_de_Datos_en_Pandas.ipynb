# %% [markdown]
# <a href="https://colab.research.google.com/github/Rolo8824/Pro/blob/main/Pandas_101_Limpieza_de_Datos_en_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Limpieza de Datos en Pandas
#
# Referencia: https://www.youtube.com/watch?v=bDhvCp3_lYw&t=172s

# %%
import pandas as pd

# %%
# Cargamos el archivo
df = pd.read_excel("/content/Customer Call List.xlsx")
df
# Out:
#    Unnamed: 0         ID  P2.1_1  P2.1_2  P2.1_3  P2.1_4  P2.1_5  P2.1_6  \
# 0           1  172363743       4       2       3       2       3       4
# 1           2  172663387       4       3       2       4       2       4
# 2           3  172221255       1       1       1       1       1       3
# 3           4  172262742       4       1       1       2       2       4
# 4           5  172096102       2       1       2       2       2       2
#
#    P2.1_7  P2.1_8  ...  P3.13  P4.1  P4.2  P4.2_OTR  P4.3  P4.4  P4.5  P4.6  \
# 0       4       4  ...      3    30     3       NaN     2     3     1    17
# 1       4       4  ...      1    38     2       NaN     3    18     1    30
# 2       1       2  ...      2    53     3       NaN     3    32     1    30
# 3       4       4  ...      2    30     1       NaN     2     6     1    11
# 4       4       4  ...      1    49     2       NaN     3    18     1    32
#
#    DRE  CIRC
# 0    1     1
# 1    1     1
# 2    1     5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %% [markdown]
# Es un dataset de (21, 8) o sea: 21 filas con 8 columnas. Observemos que algunas columnas presentan nulos como `Last_Name`, `Phone_Number`, `Do_Not_Contact`, ya que las columnas no concuerdan con el total de filas.

# %%
df = df.drop_duplicates() # Elimina duplicados
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# La función de Pandas hace exactamente eso: unificar datos duplicados

data = {
    "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
    "B": [50, 40, 40, 30, 50],
    "C": [True, False, False, False, True]
}

df_example = pd.DataFrame(data)

display(df_example.drop_duplicates())
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 3  TeamC  30  False

# %%
df = df.drop(columns = "Not_Useful_Column") # Elimina columnas
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (20, 7)

# %%
# Si queremos remover caracteres sea al inicio o al final de un string, podemos utilizar la función "strip"
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
import re # Librería para expresiones regulares

df["Phone_Number"] = df["Phone_Number"].astype(str).apply(lambda x: re.sub(r'\D', '', x))
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# ...

# %%
# Dividimos

df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', n=2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# ...

# %%
# Estandarizamos las columnas que tengan valores booleanos

df['Paying Customer'] = df['Paying Customer'].str.replace('Yes', 'Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No', 'N')

df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes', 'Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No', 'N')

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# ...

# %%
df = df.replace('N/a','')
df = df.replace('NaN','')
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 18        1019      Creed      Braton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       20 non-null     int64
#  1   First_Name       20 non-null     object
#  2   Last_Name        20 non-null     object
#  3   Phone_Number     20 non-null     object
#  4   Address          20 non-null     object
#  5   Paying Customer  20 non-null     object
#  6   Do_Not_Contact   20 non-null     object
#  7   Street_Address   20 non-null     object
#  8   State            20 non-null     object
#  9   Zip_Code         20 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 1.7+ KB

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 2         1003     Walter       White   7066950392
# 4         1005        Jon        Snow   8766783469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 19        1020     Anakin   Skywalker   8766783469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# ...

# %%
df.shape
# Out:
# (16, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       16 non-null     int64
#  1   First_Name       16 non-null     object
#  2   Last_Name        16 non-null     object
#  3   Phone_Number     16 non-null     object
#  4   Address          16 non-null     object
#  5   Paying Customer  16 non-null     object
#  6   Do_Not_Contact   16 non-null     object
#  7   Street_Address   16 non-null     object
#  8   State            16 non-null     object
#  9   Zip_Code         16 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 1.9+ KB

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)
df

# Otra forma de hacerlo
#df = df.dropna(subset="Phone_Number"), inplace=True)
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 2         1003     Walter       White   7066950392
# 4         1005        Jon        Snow   8766783469
# 7         1008   Sherlock      Holmes   8766783469
# 9         1010      Peter      Parker   1235455421
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 19        1020     Anakin   Skywalker   8766783469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
df.shape
# Out:
# (13, 10)

# %%
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1003     Walter       White   7066950392
# 2         1005        Jon        Snow   8766783469
# 3         1008   Sherlock      Holmes   8766783469
# 4         1010      Peter      Parker   1235455421
# 5         1012      Harry      Potter   7066950392
# 6         1013        Don      Draper   1235432345
# 7         1014     Leslie       Knope   8766783469
# 8         1015       Toby  Flenderson   3047622467
# 9         1016        Ron     Weasley   1235455421
# 10        1017   Michael        Scott   1236439775
# 11        1018      Clark        Kent   7066950392
# 12        1020     Anakin   Skywalker   8766783469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       13 non-null     int64
#  1   First_Name       13 non-null     object
#  2   Last_Name        13 non-null     object
#  3   Phone_Number     13 non-null     object
#  4   Address          13 non-null     object
#  5   Paying Customer  13 non-null     object
#  6   Do_Not_Contact   13 non-null     object
#  7   Street_Address   13 non-null     object
#  8   State            13 non-null     object
#  9   Zip_Code         13 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ KB
